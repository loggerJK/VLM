# %% [markdown]
# # Und

# %%
import torch
import sys
from safetensors.torch import load_file, save_file

und_weight_path = '/mnt/data1/dvlm/blip3o/checkpoints/counting_und/epoch0_step-500/adapter_model.safetensors'
ckpt = load_file(und_weight_path)

for k in sorted(ckpt.keys()):
    print(f"{k:80s} {str(tuple(ckpt[k].shape)):>30s}")
# Out:
# base_model.model.model.language_model.layers.0.mlp.down_proj.lora_A.weight                         (128, 18944)
# base_model.model.model.language_model.layers.0.mlp.down_proj.lora_B.weight                          (3584, 128)
# base_model.model.model.language_model.layers.0.mlp.gate_proj.lora_A.weight                          (128, 3584)
# base_model.model.model.language_model.layers.0.mlp.gate_proj.lora_B.weight                         (18944, 128)
# base_model.model.model.language_model.layers.0.mlp.up_proj.lora_A.weight                            (128, 3584)
# base_model.model.model.language_model.layers.0.mlp.up_proj.lora_B.weight                           (18944, 128)
# base_model.model.model.language_model.layers.0.self_attn.k_proj.lora_A.weight                       (128, 3584)
# base_model.model.model.language_model.layers.0.self_attn.k_proj.lora_B.weight                        (512, 128)
# ...

# %% [markdown]
# # Gen

# %%
import torch
import sys
from safetensors.torch import load_file

gen_weight_path = '/mnt/data1/jiwon/BLIP3o/output/counting_gen/epoch0/adapter_model.safetensors'
ckpt = load_file(gen_weight_path)

for k in sorted(ckpt.keys()):
    print(f"{k:80s} {str(tuple(ckpt[k].shape)):>30s}")
# Out:
# base_model.model.model.layers.0.mlp.down_proj.lora_A.weight                                        (128, 18944)
# base_model.model.model.layers.0.mlp.down_proj.lora_B.weight                                         (3584, 128)
# base_model.model.model.layers.0.mlp.gate_proj.lora_A.weight                                         (128, 3584)
# base_model.model.model.layers.0.mlp.gate_proj.lora_B.weight                                        (18944, 128)
# base_model.model.model.layers.0.mlp.up_proj.lora_A.weight                                           (128, 3584)
# base_model.model.model.layers.0.mlp.up_proj.lora_B.weight                                          (18944, 128)
# base_model.model.model.layers.0.self_attn.k_proj.lora_A.weight                                      (128, 3584)
# base_model.model.model.layers.0.self_attn.k_proj.lora_B.weight                                       (512, 128)
# ...
