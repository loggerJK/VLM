# %%
from datasets import load_dataset, load_from_disk, concatenate_datasets, Features, Value, Image, Sequence
dset_path = '/home/work/.project/jiwon/deepseek-janus-pro-lora/data/pixmo-count-filtered-imgContained/train'
dset = load_from_disk(dset_path)
# Out:
# Loading dataset from disk:   0%|          | 0/64 [00:00<?, ?it/s]

# %%
num_distinct = len(set(dset["image_sha256"]))
print(num_distinct)
# Out:
# 25462
