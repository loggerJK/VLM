# %%
from datasets import load_dataset, load_from_disk
from tqdm import tqdm

ds = load_from_disk("/home/work/.project/jiwon/deepseek-janus-pro-lora/data/pixmo-point-count-concat_0-20-qaFixed-v5")
# Out:
# Loading dataset from disk:   0%|          | 0/559 [00:00<?, ?it/s]

# %%
from pprint import pprint
iter_ds = iter(ds)

# %%
item = next(iter_ds)
pprint(item['label'])
pprint(item['count'])
pprint(item['question'])
pprint(item['answer'])
# Out:
# 'the word cheerios'
# 15
# ('Locate all the word cheerios. How many the word cheerios are there in the '
#  'image?. Response Example : <points x1="<coordinate of  x1>" y1="<coordinate '
#  'of  y1>" x2="<coordinate of  x2>" y2="<coordinate of  y2>" ... '
#  'x_n="<coordinate of  x_n>" y_n="<coordinate of  y_n>" alt="the word '
#  'cheerios">the word cheerios</points>.. There are **<number>** the word '
#  'cheerios in the image.')
# ('<points x1="55.2" y1="61.6" x2="20.9" y2="57.4" x3="7.2" y3="41.3" x4="7.3" '
#  'y4="22.9" x5="15.5" y5="23.2" x6="27.8" y6="23.8" x7="14.6" y7="41.9" '
#  'x8="1.5" y8="59.5" x9="51.9" y9="6.7" x10="30.7" y10="4.3" x11="17.3" '
#  'y11="3.3" x12="5.5" y12="2.2" x13="78.3" y13="10.3" x14="63.6" y14="11.3" '
#  'x15="63.2" y15="4.4" alt="the word cheerios">the word cheerios</points>. '
#  'There are **15** the word cheerios in the image.')

# %%
pprint(item['question_count'])
pprint(item['answer_count'])
# Out:
# ('How many the word cheerios are there in the image? Response Example : There '
#  'are **<number>** the word cheerios in the image.')
# 'There are **15** the word cheerios in the image.'
