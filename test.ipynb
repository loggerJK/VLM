# %%
from datasets import load_dataset, load_from_disk

dataset = load_from_disk('/home/work/.project/jiwon/deepseek-janus-pro-lora/data/pixmo_processed')
# Out:
# Loading dataset from disk:   0%|          | 0/274 [00:00<?, ?it/s]
