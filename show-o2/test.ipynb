# %%
from datasets import load_dataset, load_from_disk
dataset_name_or_path = '/home/work/.project/jiwon/deepseek-janus-pro-lora/data/pixmo-count-filtered-imgContained'
dataset = load_from_disk(dataset_name_or_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from datasets import load_dataset, load_from_disk
#       2 dataset_name_or_path = '/home/work/.project/jiwon/deepseek-janus-pro-lora/data/pixmo-count-filtered-imgContained'
# ----> 3 dataset = load_from_disk(dataset_name_or_path)
#
# File ~/.project/anaconda3/envs/showo/lib/python3.11/site-packages/datasets/load.py:1574, in load_from_disk(dataset_path, keep_in_memory, storage_options)
#    1572     return DatasetDict.load_from_disk(dataset_path, keep_in_memory=keep_in_memory, storage_options=storage_options)
#    1573 else:
# -> 1574     raise FileNotFoundError(
#    1575         f"Directory {dataset_path} is neither a `Dataset` directory nor a `DatasetDict` directory."
#    1576     )
#
# ...

# %%
dataset
# Out:
# {'image_url': 'https://live.staticflickr.com/65535/52286789057_0cd87c3865_h.jpg',
#  'image_sha256': '05941e11b4ea2bf81fcbb63f32f6d59848cf5e64936fc993a0ffe33a54c0c9fa',
#  'count': 0,
#  'points': {'x': [], 'y': []},
#  'label': 'ties',
#  'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x1067>,
#  'question': 'How many ties are there in the image? Response Example : There are **<number>** of ties in the image.',
#  'answer': 'There are **0** of ties in the image.'}

# %%
from datasets import load_dataset, load_from_disk
# dataset_name_or_path = '/home/work/.project/jiwon/deepseek-janus-pro-lora/data/pixmo-count-filtered-imgContained'
dataset_name_or_path = "Jiwon-Kang/pixmo-count-filtered-imgContained"
dataset = load_dataset(dataset_name_or_path, split='validation', streaming=True)
# Out:
# ...
# Resolving data files:   0%|          | 0/92 [00:00<?, ?it/s]

# %%
iter_dataset = iter(dataset)
for _ in range(5):
    print(next(iter_dataset))
# Out:
# {'image_url': 'https://live.staticflickr.com/65535/25664072648_85f0c493b5_h.jpg', 'image_sha256': '0ec7686fa818bde7e6ea11794164a3c8f921b6f4800fa8cd64f43acf62b3078b', 'count': 8, 'points': {'x': [], 'y': []}, 'label': 'cows', 'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x1067 at 0x7F950EEEC790>, 'question': 'How many cows are there in the image? Response Example : There are **<number>** of cows in the image.', 'answer': 'There are **8** of cows in the image.'}
# {'image_url': 'https://live.staticflickr.com/65535/49724692992_f3e8d897a2_h.jpg', 'image_sha256': 'bb2e128b56a5d2bb7efdb2bd0c937b463b0507cb4fa45a29cbe27235e18b7678', 'count': 9, 'points': {'x': [], 'y': []}, 'label': 'people', 'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1600x1067 at 0x7F950EEEE990>, 'question': 'How many people are there in the image? Response Example : There are **<number>** of people in the image.', 'answer': 'There are **9** of people in the image.'}
# ...
