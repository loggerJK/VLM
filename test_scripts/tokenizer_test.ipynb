# %%
from transformers import AutoTokenizer
import argparse

tokenizer = AutoTokenizer.from_pretrained('Alpha-VLLM/Lumina-DiMOO', trust_remote_code=True)

# %%
input_prompt = """
3. Gruenwedel, Erik (March 5, 2020). "It's a 'SpongeBob SquarePants' World at ViacomCBS". _Media Play News_. Archived from the original on August 7, 2020. Retrieved April 29, 2023.

4. Otterson, Joe (February 15, 2022). "_SpongeBob Squarepants_ Spinoff Movies, _Dora the Explorer_ Live-Action Series Set at Paramount Plus". _Variety_. Archived from the original on February 17, 2022. Retrieved April 26, 2023.

5. Giardina, Carolyn (April 25, 2023). "Netflix Animation Reveals _In Your Dreams_, a New SpongeBob Adventure and Additional _Nimona_ Voice Casting". _The Hollywood Reporter_. Archived from the original on April 25, 2023. Retrieved April 25, 2023.

6. Milligan, Mercedes (June 6, 2024). "Next on Netflix Animation Presentation Sneak-Peeks 'Wallace & Gromit' Movie, 'K-Pop: Demon Hunters,' 'Plankton' Movie, 'Motel Transylvania' and Much, Much More!". _Animation Magazine_. Archived from the original on June 8, 2024. Retrieved June 6, 2024.

7. Amidi, Amid (August 10, 2024). "Major Netflix Animation Leak Traced Back To Burbank Post-Production Company". _Cartoon Brew_. Archived from the original on January 26, 2025. Retrieved January 31, 2025.

8. Moore, Kasey (August 8, 2024). "Netflix Animation Suffers Major Leak; Multiple Movies, Series, and Anime Shared Online". _What's on Netflix_. Archived from the original on August 8, 2024. Retrieved August 8, 2024.

9. Truitt, Brian (January 17, 2025). "15 new movies you'll want to stream this year, from 'Happy Gilmore' to 'Bridget Jones'". _USA Today_. Archived from the original on January 18, 2025. Retrieved January 17, 2025.

"""

# %%
input_ids = tokenizer(input_prompt)['input_ids']
print(len(input_ids))
print(tokenizer.convert_ids_to_tokens(input_ids, skip_special_tokens=False))
# Out:
# 544
# ['Ċ', '3', '.', 'ĠGru', 'en', 'wed', 'el', ',', 'ĠErik', 'Ġ(', 'March', 'Ġ', '5', ',', 'Ġ', '2', '0', '2', '0', ').', 'Ġ"', 'It', "'s", 'Ġa', "Ġ'", 'S', 'ponge', 'Bob', 'ĠSquare', 'P', 'ants', "'", 'ĠWorld', 'Ġat', 'ĠV', 'iac', 'om', 'CBS', '".', 'Ġ_', 'Media', 'ĠPlay', 'ĠNews', '_.', 'ĠArchived', 'Ġfrom', 'Ġthe', 'Ġoriginal', 'Ġon', 'ĠAugust', 'Ġ', '7', ',', 'Ġ', '2', '0', '2', '0', '.', 'ĠRetrieved', 'ĠApril', 'Ġ', '2', '9', ',', 'Ġ', '2', '0', '2', '3', '.', 'Ċ', 'Ċ', '4', '.', 'ĠOt', 'terson', ',', 'ĠJoe', 'Ġ(', 'February', 'Ġ', '1', '5', ',', 'Ġ', '2', '0', '2', '2', ').', 'Ġ"_', 'S', 'ponge', 'Bob', 'ĠSquare', 'p', 'ants', '_', 'ĠSpin', 'off', 'ĠMovies', ',', 'Ġ_', 'D', 'ora', 'Ġthe', 'ĠExplorer', '_', 'ĠLive', '-', 'Action', 'ĠSeries', 'ĠSet', 'Ġat', 'ĠParamount', 'ĠPlus', '".', 'Ġ_', 'Var', 'iety', '_.', 'ĠArchived', 'Ġfrom', 'Ġthe', 'Ġoriginal', 'Ġon', 'ĠFebruary', 'Ġ', '1', '7', ',', 'Ġ', '2', '0', '2', '2', '.', 'ĠRetrieved', 'ĠApril', 'Ġ', '2', '6', ',', 'Ġ', '2', '0', '2', '3', '.', 'Ċ', 'Ċ', '5', '.', 'ĠGi', 'ard', 'ina', ',', 'ĠCarolyn', 'Ġ(', 'April', 'Ġ', '2', '5', ',', 'Ġ', '2', '0', '2', '3', ').', 'Ġ"', 'Netflix', 'ĠAnimation', 'ĠReveals', 'Ġ_', 'In', 'ĠYour', 'ĠDreams', '_,', 'Ġa', 'ĠNew', 'ĠSponge', 'Bob', 'ĠAdventure', 'Ġand', 'ĠAdditional', 'Ġ_', 'N', 'im', 'ona', '_', 'ĠVoice', 'ĠCasting', '".', 'Ġ_', 'The', 'ĠHollywood', 'ĠReporter', '_.', 'ĠArchived', 'Ġfrom', 'Ġthe', 'Ġoriginal', 'Ġon', 'ĠApril', 'Ġ', '2', '5', ',', 'Ġ', '2', '0', '2', '3', '.', 'ĠRetrieved', 'ĠApril', 'Ġ', '2', '5', ',', 'Ġ', '2', '0', '2', '3', '.', 'Ċ', 'Ċ', '6', '.', 'ĠMill', 'igan', ',', 'ĠMercedes', 'Ġ(', 'June', 'Ġ', '6', ',', 'Ġ', '2', '0', '2', '4', ').', 'Ġ"', 'Next', 'Ġon', 'ĠNetflix', 'ĠAnimation', 'ĠPresentation', 'ĠSne', 'ak', '-P', 'eeks', "Ġ'", 'Wall', 'ace', 'Ġ&', 'ĠG', 'rom', 'it', "'", 'ĠMovie', ',', "Ġ'", 'K', '-P', 'op', ':', 'ĠDemon', 'ĠHunters', ",'", "Ġ'", 'Pl', 'ankton', "'", 'ĠMovie', ',', "Ġ'", 'Mot', 'el', 'ĠTrans', 'ylvania', "'", 'Ġand', 'ĠMuch', ',', 'ĠMuch', 'ĠMore', '!', '".', 'Ġ_', 'Animation', 'ĠMagazine', '_.', 'ĠArchived', 'Ġfrom', 'Ġthe', 'Ġoriginal', 'Ġon', 'ĠJune', 'Ġ', '8', ',', 'Ġ', '2', '0', '2', '4', '.', 'ĠRetrieved', 'ĠJune', 'Ġ', '6', ',', 'Ġ', '2', '0', '2', '4', '.', 'Ċ', 'Ċ', '7', '.', 'ĠAm', 'idi', ',', 'ĠAmid', 'Ġ(', 'August', 'Ġ', '1', '0', ',', 'Ġ', '2', '0', '2', '4', ').', 'Ġ"', 'Major', 'ĠNetflix', 'ĠAnimation', 'ĠLeak', 'ĠTra', 'ced', 'ĠBack', 'ĠTo', 'ĠB', 'urb', 'ank', 'ĠPost', '-', 'Production', 'ĠCompany', '".', 'Ġ_', 'Cart', 'oon', 'ĠBrew', '_.', 'ĠArchived', 'Ġfrom', 'Ġthe', 'Ġoriginal', 'Ġon', 'ĠJanuary', 'Ġ', '2', '6', ',', 'Ġ', '2', '0', '2', '5', '.', 'ĠRetrieved', 'ĠJanuary', 'Ġ', '3', '1', ',', 'Ġ', '2', '0', '2', '5', '.', 'Ċ', 'Ċ', '8', '.', 'ĠMoore', ',', 'ĠK', 'ase', 'y', 'Ġ(', 'August', 'Ġ', '8', ',', 'Ġ', '2', '0', '2', '4', ').', 'Ġ"', 'Netflix', 'ĠAnimation', 'ĠSuff', 'ers', 'ĠMajor', 'ĠLeak', ';', 'ĠMultiple', 'ĠMovies', ',', 'ĠSeries', ',', 'Ġand', 'ĠAnime', 'ĠShared', 'ĠOnline', '".', 'Ġ_', 'What', "'s", 'Ġon', 'ĠNetflix', '_.', 'ĠArchived', 'Ġfrom', 'Ġthe', 'Ġoriginal', 'Ġon', 'ĠAugust', 'Ġ', '8', ',', 'Ġ', '2', '0', '2', '4', '.', 'ĠRetrieved', 'ĠAugust', 'Ġ', '8', ',', 'Ġ', '2', '0', '2', '4', '.', 'Ċ', 'Ċ', '9', '.', 'ĠTru', 'itt', ',', 'ĠBrian', 'Ġ(', 'January', 'Ġ', '1', '7', ',', 'Ġ', '2', '0', '2', '5', ').', 'Ġ"', '1', '5', 'Ġnew', 'Ġmovies', 'Ġyou', "'ll", 'Ġwant', 'Ġto', 'Ġstream', 'Ġthis', 'Ġyear', ',', 'Ġfrom', "Ġ'", 'Happy', 'ĠGil', 'more', "'", 'Ġto', "Ġ'", 'Brid', 'get', 'ĠJones', "'", '".', 'Ġ_', 'USA', 'ĠToday', '_.', 'ĠArchived', 'Ġfrom', 'Ġthe', 'Ġoriginal', 'Ġon', 'ĠJanuary', 'Ġ', '1', '8', ',', 'Ġ', '2', '0', '2', '5', '.', 'ĠRetrieved', 'ĠJanuary', 'Ġ', '1', '7', ',', 'Ġ', '2', '0', '2', '5', '.', 'Ċ', 'Ċ']

# %%
input_ids = tokenizer("<answer> answer token </answer> <padding> <padding> <padding> <padding>")['input_ids']
print(input_ids)
tokenizer.special_tokens_map

# %%
def generate_crop_size_list(num_patches, patch_size, max_ratio=4.0):
    assert max_ratio >= 1.0
    crop_size_list = []
    wp, hp = num_patches, 1
    while wp > 0:
        if max(wp, hp) / min(wp, hp) <= max_ratio:
            crop_size_list.append((wp * patch_size, hp * patch_size))
        if (hp + 1) * wp <= num_patches:
            hp += 1
        else:
            wp -= 1
    return crop_size_list

# %%
print(generate_crop_size_list(1024, 32))
